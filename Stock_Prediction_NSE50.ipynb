# %% [markdown]
# **Downloading NSE 50 Price Data**

# %%
import yfinance as yf

# Download Nifty 50 Index data
nifty_50 = yf.download("^NSEI")
nifty_50
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
# 2024-10-11  24985.300781  25028.650391  24920.050781  24964.250000
#
#                Adj Close  Volume
# Date
# 2007-09-17   4494.649902       0
# 2007-09-18   4546.200195       0
# 2007-09-19   4732.350098       0
# 2007-09-20   4747.549805       0
# 2007-09-21   4837.549805       0
# ...                  ...     ...
# 2024-10-07  24795.750000  374300
# 2024-10-08  25013.150391  333200
# 2024-10-09  24981.949219  290600
# 2024-10-10  24998.449219  261400
# 2024-10-11  24964.250000  210500
#
# [4184 rows x 6 columns]

# %%
import yfinance as yf

# List of tickers (Example: Add more NSE tickers)
tickers = ["RELIANCE.NS", "TCS.NS", "INFY.NS", "HDFCBANK.NS"]

# Download data for each ticker
data = yf.download(tickers, group_by="ticker")
data
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker                     RELIANCE.NS                                         \
# Price                             Open         High          Low        Close
# Date
# 1996-01-01 00:00:00+00:00    14.638248    14.716795    14.541850    14.691803
# 1996-01-02 00:00:00+00:00    14.656100    14.727506    14.470444    14.577553
# 1996-01-03 00:00:00+00:00    14.816763    15.491551    14.656100    14.688232
# 1996-01-04 00:00:00+00:00    14.548991    14.595404    14.356194    14.552561
# 1996-01-05 00:00:00+00:00    14.495436    14.495436    14.327632    14.452592
# ...                                ...          ...          ...          ...
# 2024-10-07 00:00:00+00:00  2787.000000  2793.000000  2722.750000  2741.449951
# 2024-10-08 00:00:00+00:00  2745.949951  2802.000000  2730.199951  2794.699951
# 2024-10-09 00:00:00+00:00  2795.050049  2801.949951  2745.000000  2749.199951
# 2024-10-10 00:00:00+00:00  2760.050049  2772.000000  2738.850098  2742.100098
# 2024-10-11 00:00:00+00:00  2740.000000  2766.550049  2737.649902  2744.199951
#
# Ticker                                               HDFCBANK.NS               \
# Price                        Adj Close       Volume         Open         High
# Date
# 1996-01-01 00:00:00+00:00     9.270975   52060684.0     3.030000     3.030000
# 1996-01-02 00:00:00+00:00     9.198881   84371654.0     2.980000     3.025000
# 1996-01-03 00:00:00+00:00     9.268724  104661939.0     2.975000     2.995000
# 1996-01-04 00:00:00+00:00     9.183110  108450132.0     2.985000     2.980000
# 1996-01-05 00:00:00+00:00     9.120028   83354233.0     2.965000     2.980000
# ...                                ...          ...          ...          ...
# 2024-10-07 00:00:00+00:00  2741.449951   11090670.0  1652.199951  1659.000000
# 2024-10-08 00:00:00+00:00  2794.699951    8510404.0  1630.000000  1656.800049
# 2024-10-09 00:00:00+00:00  2749.199951    7155305.0  1649.500000  1656.750000
# 2024-10-10 00:00:00+00:00  2742.100098   11179323.0  1639.000000  1665.449951
# 2024-10-11 00:00:00+00:00  2744.199951    3990061.0  1664.449951  1664.449951
#
# Ticker                                               ...       TCS.NS  \
# Price                              Low        Close  ...          Low
# Date                                                 ...
# 1996-01-01 00:00:00+00:00     2.925000     2.980000  ...          NaN
# 1996-01-02 00:00:00+00:00     2.950000     2.975000  ...          NaN
# 1996-01-03 00:00:00+00:00     2.950000     2.985000  ...          NaN
# 1996-01-04 00:00:00+00:00     2.940000     2.965000  ...          NaN
# 1996-01-05 00:00:00+00:00     2.950000     2.960000  ...          NaN
# ...                                ...          ...  ...          ...
# 2024-10-07 00:00:00+00:00  1613.000000  1617.800049  ...  4229.399902
# 2024-10-08 00:00:00+00:00  1622.000000  1651.050049  ...  4203.950195
# 2024-10-09 00:00:00+00:00  1628.699951  1633.150024  ...  4246.700195
# 2024-10-10 00:00:00+00:00  1632.500000  1662.400024  ...  4198.600098
# 2024-10-11 00:00:00+00:00  1643.250000  1651.000000  ...  4112.450195
#
# Ticker                                                              INFY.NS  \
# Price                            Close    Adj Close     Volume         Open
# Date
# 1996-01-01 00:00:00+00:00          NaN          NaN        NaN     0.794921
# 1996-01-02 00:00:00+00:00          NaN          NaN        NaN     0.794921
# 1996-01-03 00:00:00+00:00          NaN          NaN        NaN     0.798828
# 1996-01-04 00:00:00+00:00          NaN          NaN        NaN     0.791015
# 1996-01-05 00:00:00+00:00          NaN          NaN        NaN     0.784179
# ...                                ...          ...        ...          ...
# 2024-10-07 00:00:00+00:00  4272.850098  4272.850098  1472619.0  1923.199951
# 2024-10-08 00:00:00+00:00  4253.250000  4253.250000  1541867.0  1937.900024
# 2024-10-09 00:00:00+00:00  4252.950195  4252.950195  1082504.0  1952.550049
# 2024-10-10 00:00:00+00:00  4227.399902  4227.399902  2378875.0  1957.900024
# 2024-10-11 00:00:00+00:00  4149.200195  4149.200195  5759183.0  1918.000000
#
# Ticker                                                                         \
# Price                             High          Low        Close    Adj Close
# Date
# 1996-01-01 00:00:00+00:00     0.796679     0.791015     0.796679     0.515559
# 1996-01-02 00:00:00+00:00     0.798828     0.793457     0.793457     0.513474
# 1996-01-03 00:00:00+00:00     0.798828     0.798828     0.798828     0.516949
# 1996-01-04 00:00:00+00:00     0.794921     0.791015     0.793554     0.513536
# 1996-01-05 00:00:00+00:00     0.784179     0.784179     0.784179     0.507469
# ...                                ...          ...          ...          ...
# 2024-10-07 00:00:00+00:00  1942.000000  1916.050049  1934.300049  1934.300049
# 2024-10-08 00:00:00+00:00  1957.949951  1906.349976  1948.550049  1948.550049
# 2024-10-09 00:00:00+00:00  1977.000000  1945.099976  1952.750000  1952.750000
# 2024-10-10 00:00:00+00:00  1964.000000  1914.099976  1919.000000  1919.000000
# 2024-10-11 00:00:00+00:00  1947.000000  1910.099976  1935.099976  1935.099976
#
# Ticker
# Price                       Volume
# Date
# 1996-01-01 00:00:00+00:00   204800
# 1996-01-02 00:00:00+00:00   204800
# 1996-01-03 00:00:00+00:00   102400
# 1996-01-04 00:00:00+00:00   307200
# 1996-01-05 00:00:00+00:00    51200
# ...                            ...
# 2024-10-07 00:00:00+00:00  6112575
# 2024-10-08 00:00:00+00:00  5637391
# 2024-10-09 00:00:00+00:00  4857163
# 2024-10-10 00:00:00+00:00  4782119
# 2024-10-11 00:00:00+00:00  4709431
#
# [7230 rows x 24 columns]

# %%
nifty_50_data = nifty_50
nifty_50_data.to_csv("nifty_50.csv")

# %%
nifty_50_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
# 2024-10-11  24985.300781  25028.650391  24920.050781  24964.250000
#
#                Adj Close  Volume
# Date
# 2007-09-17   4494.649902       0
# 2007-09-18   4546.200195       0
# 2007-09-19   4732.350098       0
# 2007-09-20   4747.549805       0
# 2007-09-21   4837.549805       0
# ...                  ...     ...
# 2024-10-07  24795.750000  374300
# 2024-10-08  25013.150391  333200
# 2024-10-09  24981.949219  290600
# 2024-10-10  24998.449219  261400
# 2024-10-11  24964.250000  210500
#
# [4184 rows x 6 columns]

# %%
nifty_50_data.index
# Out:
# DatetimeIndex(['2007-09-17', '2007-09-18', '2007-09-19', '2007-09-20',
#                '2007-09-21', '2007-09-24', '2007-09-25', '2007-09-26',
#                '2007-09-27', '2007-09-28',
#                ...
#                '2024-09-27', '2024-09-30', '2024-10-01', '2024-10-03',
#                '2024-10-04', '2024-10-07', '2024-10-08', '2024-10-09',
#                '2024-10-10', '2024-10-11'],
#               dtype='datetime64[ns]', name='Date', length=4184, freq=None)

# %% [markdown]
# **Cleaning and Visualising our Stock Market Data**

# %%
nifty_50_data.plot.line(y='Close', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Setting Up our Targer for Machine Learning

# %%
nifty_50_data["Tomorrow"] = nifty_50_data["Close"].shift(-1)

# %%
nifty_50_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
# 2024-10-11  24985.300781  25028.650391  24920.050781  24964.250000
#
#                Adj Close  Volume      Tomorrow
# Date
# 2007-09-17   4494.649902       0   4546.200195
# 2007-09-18   4546.200195       0   4732.350098
# 2007-09-19   4732.350098       0   4747.549805
# 2007-09-20   4747.549805       0   4837.549805
# 2007-09-21   4837.549805       0   4932.200195
# ...                  ...     ...           ...
# 2024-10-07  24795.750000  374300  25013.150391
# 2024-10-08  25013.150391  333200  24981.949219
# 2024-10-09  24981.949219  290600  24998.449219
# 2024-10-10  24998.449219  261400  24964.250000
# 2024-10-11  24964.250000  210500           NaN
#
# [4184 rows x 7 columns]

# %%
nifty_50_data["Target"] = (nifty_50_data["Tomorrow"] > nifty_50_data["Close"]).astype(int)
nifty_50_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
# 2024-10-11  24985.300781  25028.650391  24920.050781  24964.250000
#
#                Adj Close  Volume      Tomorrow  Target
# Date
# 2007-09-17   4494.649902       0   4546.200195       1
# 2007-09-18   4546.200195       0   4732.350098       1
# 2007-09-19   4732.350098       0   4747.549805       1
# 2007-09-20   4747.549805       0   4837.549805       1
# 2007-09-21   4837.549805       0   4932.200195       1
# ...                  ...     ...           ...     ...
# 2024-10-07  24795.750000  374300  25013.150391       1
# 2024-10-08  25013.150391  333200  24981.949219       0
# 2024-10-09  24981.949219  290600  24998.449219       1
# 2024-10-10  24998.449219  261400  24964.250000       0
# 2024-10-11  24964.250000  210500           NaN       0
#
# [4184 rows x 8 columns]

# %%
nifty_50_data = nifty_50_data.loc["1990-01-01":].copy()
nifty_50_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
# 2024-10-11  24985.300781  25028.650391  24920.050781  24964.250000
#
#                Adj Close  Volume      Tomorrow  Target
# Date
# 2007-09-17   4494.649902       0   4546.200195       1
# 2007-09-18   4546.200195       0   4732.350098       1
# 2007-09-19   4732.350098       0   4747.549805       1
# 2007-09-20   4747.549805       0   4837.549805       1
# 2007-09-21   4837.549805       0   4932.200195       1
# ...                  ...     ...           ...     ...
# 2024-10-07  24795.750000  374300  25013.150391       1
# 2024-10-08  25013.150391  333200  24981.949219       0
# 2024-10-09  24981.949219  290600  24998.449219       1
# 2024-10-10  24998.449219  261400  24964.250000       0
# 2024-10-11  24964.250000  210500           NaN       0
#
# [4184 rows x 8 columns]

# %% [markdown]
# **Training an Initial Machine Learning Model**

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
train = nifty_50_data.iloc[:-100]
test = nifty_50_data.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 1.0

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Building a Backtesting System**

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
predictions = backtest(nifty_50_data, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    928
# 0    756
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5495689655172413

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.55285
# 0    0.44715
# Name: count, dtype: float64

# %% [markdown]
# **Adding Additional Predictors to our Model**

# %%
horizons = [2, 5, 60, 250, 1000]
new_predictors = []

for horizon in horizons:
    # Calculate the rolling averages
    rolling_averages = nifty_50_data.rolling(horizon).mean()

    # Create the ratio column with .loc[]
    ratio_column = f"Close_Ratio_{horizon}"
    nifty_50_data.loc[:, ratio_column] = nifty_50_data["Close"] / rolling_averages["Close"]

    # Create the trend column with .loc[]
    trend_column = f"Trend_{horizon}"
    nifty_50_data.loc[:, trend_column] = nifty_50_data["Target"].shift(1).rolling(horizon).sum()

    # Append the newly created columns to the list of new predictors
    new_predictors += [ratio_column, trend_column]

# %%
# Display the modified DataFrame with new columns
print(nifty_50_data.head())
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098  4732.350098
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805  4747.549805
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805  4837.549805
#
#             Volume     Tomorrow  Target  Close_Ratio_2  Trend_2  \
# Date
# 2007-09-17       0  4546.200195       1            NaN      NaN
# 2007-09-18       0  4732.350098       1       1.005702      NaN
# 2007-09-19       0  4747.549805       1       1.020062      2.0
# 2007-09-20       0  4837.549805       1       1.001603      2.0
# 2007-09-21       0  4932.200195       1       1.009390      2.0
#
#             Close_Ratio_5  Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  \
# Date
# 2007-09-17            NaN      NaN             NaN       NaN              NaN
# 2007-09-18            NaN      NaN             NaN       NaN              NaN
# 2007-09-19            NaN      NaN             NaN       NaN              NaN
# 2007-09-20            NaN      NaN             NaN       NaN              NaN
# 2007-09-21        1.03551      NaN             NaN       NaN              NaN
#
#             Trend_250  Close_Ratio_1000  Trend_1000
# Date
# 2007-09-17        NaN               NaN         NaN
# 2007-09-18        NaN               NaN         NaN
# 2007-09-19        NaN               NaN         NaN
# 2007-09-20        NaN               NaN         NaN
# 2007-09-21        NaN               NaN         NaN

# %%
nifty_50_data = nifty_50_data.dropna()
nifty_50_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2024-10-04  25181.900391  25485.050781  24966.800781  25014.599609
# 2024-10-07  25084.099609  25143.000000  24694.349609  24795.750000
# 2024-10-08  24832.199219  25044.000000  24756.800781  25013.150391
# 2024-10-09  25065.800781  25234.050781  24947.699219  24981.949219
# 2024-10-10  25067.050781  25134.050781  24979.400391  24998.449219
#
#                Adj Close  Volume      Tomorrow  Target
# Date
# 2007-09-17   4494.649902       0   4546.200195       1
# 2007-09-18   4546.200195       0   4732.350098       1
# 2007-09-19   4732.350098       0   4747.549805       1
# 2007-09-20   4747.549805       0   4837.549805       1
# 2007-09-21   4837.549805       0   4932.200195       1
# ...                  ...     ...           ...     ...
# 2024-10-04  25014.599609  374900  24795.750000       0
# 2024-10-07  24795.750000  374300  25013.150391       1
# 2024-10-08  25013.150391  333200  24981.949219       0
# 2024-10-09  24981.949219  290600  24998.449219       1
# 2024-10-10  24998.449219  261400  24964.250000       0
#
# [4183 rows x 8 columns]

# %% [markdown]
# Improving Our Model

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=500, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors]) [:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(nifty_50_data, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    1462
# 1.0     221
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5746606334841629
